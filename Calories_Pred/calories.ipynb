# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


# %matplotlib inline

# %%
calories1 = pd.read_csv("exercise.csv")
calories2 = pd.read_csv("calories.csv")
calories = pd.merge(calories1, calories2, how='outer')

# %%
sns.pairplot(calories)

# %%
cols = ["Duration", "Body_Temp", "Weight", "Height"]

filtered = calories.copy()

plt.figure()
sns.heatmap(filtered[col].corr(), annot=True, cmap="coolwarm")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 6
#       3 filtered = calories.copy()
#       5 plt.figure()
# ----> 6 sns.heatmap(filtered[col].corr(), annot=True, cmap="coolwarm")
#       7 plt.show()
#
# TypeError: Series.corr() missing 1 required positional argument: 'other'

# %%
calories.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
# Remove outliers using IQR (without outliers the scales of the plots are good and the data can be better visualized)
cols = ["Duration", "Body_Temp", "Weight", "Height"]

filtered = calories.copy()

for col in cols:
    Q1 = filtered[col].quantile(0.25)
    Q3 = filtered[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    filtered = filtered[(filtered[col] >= lower) & (filtered[col] <= upper)]

# %%
sns.pairplot(calories)
